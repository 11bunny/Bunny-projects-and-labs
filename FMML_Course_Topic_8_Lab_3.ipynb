# %% [markdown]
# <a href="https://colab.research.google.com/github/11bunny/Bunny-projects-and-labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-03 16:00:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   118MB/s    in 0.6s
#
# 2024-04-03 16:00:50 (118 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22348  1603.01029v2  Non-Gaussian component analysis (NGCA) is an u...  stat
# 27010  1701.08393v3  We propose a deep convolutional neural network...    cs
# 8383   1602.02543v1  The expectation and the mean of partitions gen...    cs
# 6864   1706.10031v1  We propose a new neural sequence model trainin...  stat
# 33716  1602.05925v1  Hierarchical Temporal Memory (HTM) is a biolog...    cs
# ...             ...                                                ...   ...
# 14683   1002.0485v1  We are developing electronic dictionaries and ...    cs
# 19192   1304.2345v1  KNET is a general-purpose shell for constructi...    cs
# 30060  1711.06368v1  This paper introduces an online model for obje...    cs
# 16187  1610.06498v1  The authorship attribution is a problem of con...    cs
# 26777  1611.08563v6  We present a deep-learning framework for real-...    cs
#
#                                                    title  year  \
# 22348  Whitening-Free Least-Squares Non-Gaussian Comp...  2016
# 27010  Faceness-Net: Face Detection through Deep Faci...  2017
# 8383                    Homogeneity of Cluster Ensembles  2016
# 6864   Neural Sequence Model Training via $α$-diverge...  2017
# 33716                      Encoding Data for HTM Systems  2016
# ...                                                  ...   ...
# 14683  Morphological study of Albanian words, and pro...  2010
# 19192  KNET: Integrating Hypermedia and Bayesian Mode...  2013
# 30060  Mobile Video Object Detection with Temporally-...  2017
# 16187  Authorship Attribution Based on Life-Like Netw...  2016
# 26777  Online Real-time Multiple Spatiotemporal Actio...  2016
#
#                                                 keywords
# 22348  [component, unsupervised, dimension, reduction...
# 27010  [convolutional, detection, leveraging, attribu...
# 8383   [expectation, partitions, generated, challenge...
# 6864   [objective, divergence, demonstrate, objective...
# 33716  [hierarchical, biologically, intelligence, tec...
# ...                                                  ...
# 14683  [developing, electronic, dictionaries, transdu...
# 19192  [constructing, graphical, representations, kno...
# 30060  [introduces, detection, detection, convolution...
# 16187  [authorship, attribution, considerable, practi...
# 26777  [framework, localisation, classification, pred...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22348    [component, unsupervised, dimension, reduction...
# 27010    [convolutional, detection, leveraging, attribu...
# 8383     [expectation, partitions, generated, challenge...
# 6864     [objective, divergence, demonstrate, objective...
# 33716    [hierarchical, biologically, intelligence, tec...
#                                ...
# 38432    [describes, nonlinear, thresholding, ramachand...
# 31070    [structure, segmentation, contextual, informat...
# 11851    [investigate, contextual, nonparametric, compa...
# 22062    [regularization, estimation, correlated, varia...
# 24816    [introduce, architecture, segmentation, repres...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8870 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="900fe303-3dcd-48e2-a528-daa05aaa40aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("900fe303-3dcd-48e2-a528-daa05aaa40aa")) {                    Plotly.newPlot(                        "900fe303-3dcd-48e2-a528-daa05aaa40aa",                        [{"x":["projection","demonstrate","developed","contaminated","unsupervised","generalization","whitening","superiority","components","dimensional","dimension","reduction","dependent","conditioned","estimation","eigendecomposition","experimentally","independent","covariance","gradients","approaches","analytically","component","attributes","unconstrained","phenomenon","occlusion","variations","benchmarks","arrangement","partially","detection","including","supervision","carefully","considering","consideration","structure","promising","formulated","leveraging","detectors","convolutional","performance","challenging","responses","mechanism","observation","motivates","homogeneity","increasing","inference","contribution","exceptional","uniqueness","expectation","clustering","stability","generated","practical","consensus","partition","introduce","challenges","partitions","statistical","empirical","diversity","conditions","ensembles","algorithm","sufficient","efficient","reinforcement","minimization","experimental","considered","divergence","minimizing","functions","outperforms","corresponds","translation","generalizes","objective","likelihood","requirements","processes","biologically","neocortex","representations","technology","available","intelligence","hierarchical","architecture","distributed","countries","alternative","capability","variability","discrimination","handwriting","observations","recognition","programming","automation","distortions","handwritten","correlations","especially","efficiency","artificial","languages","sensitive","traditional","generation","evaluator","incorporated","encourages","unlabeled","laborious","retrieval","advantages","annotations","discriminativeness","sentences","effectiveness","discriminate","generating","framework","additional","replicating","correspondence","discriminative","naturally","captioning","individual","community","different","introduces","googlenet","substantially","technique","incorporate","respectively","architectural","introduced","backpropagation","information","forwarding","processing","vanishing","described","convergence","investigate","algorithms","particular","investigation","stochastic","regularized","decompose","optimization","conducted","experiments","theoretical","conventional","comparatively","probability","popularity","orthogonality","dictionary","prescribed","combinations","nonlinear","flexibility","synthetic","approximation","promoting","documented","environments","guarantees","cognition","understand","cognitive","essential","behavioral","neuroscience","implemented","relationships","biological","computational","conditional","variances","envelopes","connected","autocorrelations","influences","uncorrelated","multivariate"],"y":[48,517,205,7,124,105,0,42,105,179,69,87,76,15,195,1,50,148,25,29,404,11,116,54,20,24,34,76,94,6,66,351,243,50,31,60,27,366,109,39,43,41,379,884,263,34,110,71,7,6,98,216,71,7,10,26,155,50,164,153,19,28,340,118,17,160,146,42,137,20,812,69,416,114,75,406,122,32,46,234,272,25,99,30,167,73,67,114,19,2,223,46,287,102,100,257,93,14,82,56,24,14,12,71,351,122,15,9,23,33,114,141,161,98,51,184,130,3,30,10,47,4,102,76,73,2,75,202,12,100,525,117,2,31,92,67,20,137,74,704,79,6,46,245,59,89,13,124,17,670,2,279,9,75,134,145,584,282,27,121,51,8,307,71,555,138,102,1,175,16,2,62,3,33,52,24,121,127,6,3,86,71,20,85,43,82,12,8,86,62,51,282,85,5,2,71,1,10,1,26],"type":"bar"},{"x":["projection","demonstrate","developed","co ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8258333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Codeco</span> <span style=''>A</span> <span style=''>Grammar</span> <span style=''>Notation</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.48148148148148157);'>Controlled</span> <span style=''>Natural</span> <span style=''>Language</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3973799126637554);'>Predictive</span> <span style=''>Editors</span> <br/><br/><span style=''>Existing</span> <span style=''>grammar</span> <span style='background-color:rgba(0, 255, 0, 0.31147540983606564);'>frameworks</span> <span style=''>do</span> <span style=''>not</span> <span style=''>work</span> <span style=''>out</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>well</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.48148148148148157);'>controlled</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.9215686274509804);'>languages</span> <span style=''>(CNL)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>if</span> <span style=''>they</span> <span style=''>are</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3973799126637554);'>predictive</span> <span style=''>editors</span> <span style=''>I</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style=''>new</span> <span style=''>grammar</span> <span style=''>notation</span> <span style=''>called</span> <span style=''>Codeco</span> <span style=''>which</span> <span style=''>is</span> <span style=''>designed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specifically</span> <span style=''>for</span> <span style=''>CNLs</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3973799126637554);'>predictive</span> <span style=''>editors</span> <span style=''>Two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>parsers</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implemented</span> <span style=''>and</span> <span style=''>a</span> <span style=''>large</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>Attempto</span> <span style='background-color:rgba(0, 255, 0, 0.48148148148148157);'>Controlled</span> <span style=''>English</span> <span style=''>(ACE)</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3055555555555556);'>represented</span> <span style=''>in</span> <span style=''>Codeco</span> <span style=''>The</span> <span style=''>results</span> <span style=''>show</span> <span style=''>that</span> <span style=''>Codeco</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>adequate</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>Ranking</span> <span style=''>Pursuit</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preference</span> <span style=''>learningranking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximates</span> <span style=''>the</span> <span style=''>true</span> <span style=''>utility</span> <span style=''>function</span> <span style=''>by</span> <span style=''>a</span> <span style=''>weighted</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>basis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>using</span> <span style=''>the</span> <span style=''>squared</span> <span style=''>loss</span> <span style=''>on</span> <span style=''>pairs</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>and</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>matching</span> <span style=''>pursuit</span> <span style=''>method</span> <span style=''>It</span> <span style=''>can</span> <span style=''>operate</span> <span style=''>both</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>and</span> <span style=''>a</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>setting</span> <span style=''>and</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>search</span> <span style=''>for</span> <span style=''>multiple</span> <span style=''>near</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>combined</span> <span style=''>ranking</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>tasks</span> <span style=''>In</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>several</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>when</span> <span style=''>taking</span> <span style=''>into</span> <span style=''>account</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>and</span> <span style=''>performs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparably</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Control</span> <span style=''>of</span> <span style=''>Complex</span> <span style=''>Systems</span> <span style=''>Using</span> <span style=''>Bayesian</span> <span style=''>Networks</span> <span style=''>and</span> <span style=''>Genetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <br/><br/><span style=''>A</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Bayesian</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>genetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>control</span> <span style=''>the</span> <span style=''>fermentation</span> <span style=''>process</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>input</span> <span style=''>and</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.42857142857142855);'>variables</span> <span style=''>is</span> <span style=''>modelled</span> <span style=''>using</span> <span style=''>Bayesian</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>that</span> <span style=''>is</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>hybrid</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>method</span> <span style=''>A</span> <span style=''>feedback</span> <span style=''>loop</span> <span style=''>based</span> <span style=''>on</span> <span style=''>genetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>change</span> <span style=''>input</span> <span style='background-color:rgba(255, 0, 0, 0.42857142857142855);'>variables</span> <span style=''>so</span> <span style=''>that</span> <span style=''>the</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.42857142857142855);'>variables</span> <span style=''>are</span> <span style=''>as</span> <span style=''>close</span> <span style=''>to</span> <span style=''>the</span> <span style=''>desired</span> <span style=''>target</span> <span style=''>as</span> <span style=''>possible</span> <span style=''>without</span> <span style=''>the</span> <span style=''>loss</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style=''>level</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>that</span> <span style=''>the</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>gives</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>is</span> <span style=''>found</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>distance</span> <span style=''>between</span> <span style=''>the</span> <span style=''>desired</span> <span style=''>target</span> <span style=''>and</span> <span style=''>measured</span> <span style=''>outputs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>HNP3</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style=''>Point</span> <span style=''>Process</span> <span style=''>for</span> <span style=''>Modeling</span> <span style=''>Content</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Diffusion</span> <span style=''>over</span> <span style=''>Social</span> <span style=''>Media</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>modeling</span> <span style=''>temporal</span> <span style=''>events</span> <span style=''>with</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>longitudinal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependency</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>sources</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>takes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multidimensional</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>for</span> <span style=''>modeling</span> <span style=''>time</span> <span style=''>of</span> <span style=''>events</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intensity</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>process</span> <span style=''>is</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intensities</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>grows</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>temporal</span> <span style=''>patterns</span> <span style=''>of</span> <span style=''>data</span> <span style=''>Moreover</span> <span style=''>it</span> <span style=''>utilizes</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>model</span> <span style=''>marks</span> <span style=''>of</span> <span style=''>events</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>capabilities</span> <span style=''>allow</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>to</span> <span style=''>adapt</span> <span style=''>its</span> <span style=''>temporal</span> <span style=''>and</span> <span style=''>topical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>according</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>data</span> <span style=''>which</span> <span style=''>makes</span> <span style=''>it</span> <span style=''>a</span> <span style=''>suitable ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12080057183702644)
# 	information (0.2394567548248749)
# 	segmentation (0.06468906361686919)
# 	processing (0.09971408148677627)
# 	architecture (0.09185132237312366)
# 	experimental (0.1451036454610436)
# 	different (0.2516082916368835)
# 	detection (0.12544674767691208)
# 	recognition (0.12544674767691208)
# 	convolutional (0.13545389563974267)
#
# Some Statistics words are:
# 	statistical (0.14885114885114886)
# 	stochastic (0.13836163836163837)
# 	algorithm (0.3956043956043956)
# 	distribution (0.18581418581418582)
# 	variables (0.14985014985014986)
# 	estimation (0.18281718281718282)
# 	theoretical (0.16333666333666333)
# 	dimensional (0.1913086913086913)
# 	inference (0.2057942057942058)
# 	regression (0.1863136863136863)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e104b175-1139-464b-a189-809cb66925b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e104b175-1139-464b-a189-809cb66925b8")) {                    Plotly.newPlot(                        "e104b175-1139-464b-a189-809cb66925b8",                        [{"x":["projection","demonstrate","developed","contaminated","unsupervised","generalization","whitening","superiority","components","dimensional","dimension","reduction","dependent","conditioned","estimation","eigendecomposition","experimentally","independent","covariance","gradients","approaches","analytically","component","attributes","unconstrained","phenomenon","occlusion","variations","benchmarks","arrangement","partially","detection","including","supervision","carefully","considering","consideration","structure","promising","formulated","leveraging","detectors","convolutional","performance","challenging","responses","mechanism","observation","motivates","homogeneity","increasing","inference","contribution","exceptional","uniqueness","expectation","clustering","stability","generated","practical","consensus","partition","introduce","challenges","partitions","statistical","empirical","diversity","conditions","ensembles","algorithm","sufficient","efficient","reinforcement","minimization","experimental","considered","divergence","minimizing","functions","outperforms","corresponds","translation","generalizes","objective","likelihood","requirements","processes","biologically","neocortex","representations","technology","available","intelligence","hierarchical","architecture","distributed","countries","alternative","capability","variability","discrimination","handwriting","observations","recognition","programming","automation","distortions","handwritten","correlations","especially","efficiency","artificial","languages","sensitive","traditional","generation","evaluator","incorporated","encourages","unlabeled","laborious","retrieval","advantages","annotations","discriminativeness","sentences","effectiveness","discriminate","generating","framework","additional","replicating","correspondence","discriminative","naturally","captioning","individual","community","different","introduces","googlenet","substantially","technique","incorporate","respectively","architectural","introduced","backpropagation","information","forwarding","processing","vanishing","described","convergence","investigate","algorithms","particular","investigation","stochastic","regularized","decompose","optimization","conducted","experiments","theoretical","conventional","comparatively","probability","popularity","orthogonality","dictionary","prescribed","combinations","nonlinear","flexibility","synthetic","approximation","promoting","documented","environments","guarantees","cognition","understand","cognitive","essential","behavioral","neuroscience","implemented","relationships","biological","computational","conditional","variances","envelopes","connected","autocorrelations","influences","uncorrelated","multivariate","connectivity","identified","conditionally","separation","dependence","exploiting","resulting","effective","separated","autoregressive","automatic","causality","discovered","interesting","important","convolution","infinitely","tractable","divisible","distributions","applications","following","symmetric","instances","gaussians","invariant","computation","expecting","distinguish","hyperbolic","continuous","distribution","fundamental","pointwise","generalized","developing","conjugate","combination","characteristic","generalize","reference","derivatives","parameterization","surprising","approximates","transport","accelerated","formulation","reconstructed","analytical","environment","principles","considerably" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	whitening
# 	divisible
# 	hyperbolic
# 	methylation
# 	repulsive
# 	cytometry
# 	cytometric
# 	parallelizes
# 	econometrics
# 	nonparametrically
# 	geodesics
# 	advertisement
# 	idealized
# 	distilling
# 	schizophrenia
# 	reconstructive
# 	effectivity
# 	byzantine
# 	geostatistical
# 	normalising
# Some words which never appear in Statistics papers:
# 	neocortex
# 	discriminativeness
# 	replicating
# 	forwarding
# 	photometric
# 	subjected
# 	prerequisite
# 	triggered
# 	autonomously
# 	calibrates
# 	morphable
# 	attaching
# 	minimalist
# 	formalisms
# 	directionality
# 	roughness
# 	observers
# 	metaheuristics
# 	assistant
# 	phonological

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.073518564052127e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7841666666666667
